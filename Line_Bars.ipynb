# %%
# %matplotlib inline

# %%
#Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt() Object_oriented
ax = plt.axes()
ax.plot(x_axis, y_axis)
ply.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\PAUROD~1\AppData\Local\Temp/ipykernel_12372/1224720708.py in <module>
#       2 ax = plt.axes()
#       3 ax.plot(x_axis, y_axis)
# ----> 4 ply.show()
#
# NameError: name 'ply' is not defined

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label = "Boston")
# Create labels for the x and y values
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y lim between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("Pyber Fare by Month")
# Add the legend
plt.legend()

# %%
# Create the plot 
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create lables for x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y lim between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("Pyber Fare by Month")
# Add a grid
plt.grid()
# Add legend
plt.legend()

# %%
# Create the plot
# Change color to green and markers to diamonds
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create lables for x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y lim between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("Pyber Fare by Month")
# Add a grid
plt.grid()
# Add legend for Boston
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create plot
plt.bar(x_axis, y_axis, color="green", label ='Boston')
# Create labels x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create title
plt.title("Pyber Fare by Month")
# Add legend
plt.legend()

# %%
# Create plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Switch x and y axis
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create plot
# Chain gca() and invert_yaxis()
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Create plot
# Change color to magenta, add title
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Chain gca() and invert_yaxis()
plt.gca().invert_yaxis()
# Add axis labes
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Create title
plt.title("Pyber Fare by Month")
# Add legend
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create vertical bar chart with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)

# %%
# Create horizontal bar plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
#switch axis
ax.barh(y_axis, x_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
# Change color to cyan, label for data
ax.barh(x_axis, y_axis, color="c", label='Chicago')
# Invert y axis so jan is at top
plt.gca().invert_yaxis()
# Add axis labels
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Add title
plt.title("Pyber Fare by Month")
# Add legend
plt.legend()
